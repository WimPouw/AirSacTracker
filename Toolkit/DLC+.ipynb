# %% [markdown]
# # Module to process video DLC model
#
# This module belongs to the manuscript "Burchardt, L., Van de Sande, Y., Kehy, M., Gamba, M., Ravignani, A., Pouw, W. A complete computational and data toolkit for the dynamic study of laryngeal air sacs in Siamang (Symphalangus syndactylus) with applications for spherical tracking in other animals".
#
# This contains a module for tracking Siamang head and air sack postures. The following keypoints will be tracked by a trained resnet 101 model:
# - UpperLip
# - LowerLip
# - Nose
# - EyeBridge
# - Start_outline_outer_left
# - Start_outline_outer_right
# - LowestPoint_outline
# - MidLowleft_outline
# - MidLowright_outline
#
# Note that Deeplabcut needs to be installed (in command prompt "pip install -r requirements.txt"). By default the CPU version is installed. Please see the original documentation of DeepLabCut to ensure GPU compatibility if you want to speed up the tracking process. We do recommend to use a GPU supported deeplabcut.
#
# The trained resnet101 model needs to be downloaded first from google drive; so please go to the following folder and follow the download link and download to that folder: "./AirSacTracker/Toolkit/module_process_video_DLC_model/trained_model_and_metainfo/dlc-models/iteration-0/Deep_AirSacTrackingV1Jan1-trainset95shuffle1/train/".

# %%
# load in all the packages needed:

# processing the videos with deeplabcut:
import deeplabcut
import os
import shutil
from os.path import isfile, join
from IPython.display import Video

# performing a circle estimation with Landau algorithm:
import glob
import pandas as pd
import numpy as np
from pprint import pprint

# hough transformation
import cv2  # image/video processing
import pandas as pd  # data wranlging/csv
from skimage import io, feature, color, measure, draw, img_as_float  # image processing
import numpy as np  # data wrangling
import os  # folder structuring
from os.path import isfile, join  # for basic file operations
from tqdm import tqdm  # for a process bar
from IPython.display import Video  # for showing a video

# plot landau circles on processed video:
import os
from os import listdir
from os.path import isfile, join
from tabulate import tabulate
import cv2
import pandas as pd
import math
# Out:
# Loading DLC 2.3.5...

# %% [markdown]
# ## Part 1: processing your video with DLC

# %%
# load the pre-trained model settings
config_path = "./module_process_video_DLC_model/trained_model_and_metainfo/config.yaml"

# where are we going to save our tracked results to?
output_dir = "./module_process_video_DLC_model/results/replications_Y_07_23/"

# set videofolder from which we are going to process
videofolder = "./module_process_video_DLC_model/videos/"

# loading in the videos
vids = [f for f in os.listdir(videofolder) if isfile(join(videofolder, f))]

# %%
# display the first video in the set
Video(videofolder + vids[0], width=300, height=200)
# Out:
# <video src="./module_process_video_DLC_model/videos/example8.mp4" controls  width="300"  height="200">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# loop through each video and track using DLC
for i in vids:  # add the image folder name to get the full path
    video_path = videofolder + i
    # analyze the video using the pre-trained model
    deeplabcut.analyze_videos(
        config_path,
        [video_path],
        save_as_csv=False,
        videotype=".mp4",
        destfolder=output_dir,
    )
    # if you only want csv's than you uncomment the next line instead (note though that the labeling from deeplabcut requires .h5 instead of csv)
    # deeplabcut.analyze_videos(config_path, [video_path],save_as_csv=False, videotype='.mp4', destfolder=output_dir)
# convert H5 files to CSV files so you have the data in both extensions
deeplabcut.analyze_videos_converth5_to_csv(output_dir, ".mp4")
# Out:
# Using snapshot-500000 for model ./module_process_video_DLC_model/trained_model_and_metainfo/dlc-models/iteration-0/Deep_AirSacTrackingV1Jan1-trainset95shuffle1
# /Users/dlc/miniconda/envs/DEEPLABCUT_M1/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Metal device set to: Apple M2
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2023-08-04 10:25:35.682093: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Starting to analyze %  ./module_process_video_DLC_model/videos/example8.mp4
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.
# Found output file for scorer: DLC_resnet101_Deep_AirSacTrackingV1Jan1shuffle1_500000
# Converting ./module_process_video_DLC_model/results/replications_Y_07_23/example8DLC_resnet101_Deep_AirSacTrackingV1Jan1shuffle1_500000.h5...
# All H5 files were converted to CSV.

# %% [markdown]
# ## Part 2: A Hough Transformation

# %%
# load data:

savename = "example8"
path = "./module_circleestimation/data/"
path_output = "./module_circleestimation/results/replications_Y/"
timeseries_folder = "./module_plotcirclesonvideos/timeseries/"
pattern = "*.csv"
list_of_files = glob.glob(path + pattern)

print("these are the files that you selected to be processed:")
pprint(list_of_files)
# Out:
# ['/Users/dlc/Documents/onderzoek/AirSacTracker/Toolkit/module_circleestimation/data/_Opp_August_14_Session_1_zoom_syncedboom_5_3_FajarDLC_resnet101_Deep_AirSacTrackingV1Jan1shuffle1_500000.csv',
#  '/Users/dlc/Documents/onderzoek/AirSacTracker/Toolkit/module_circleestimation/data/_Opp_August_14_Session_1_zoom_syncedboom_2_2_FajarDLC_resnet101_Deep_AirSacTrackingV1Jan1shuffle1_500000.csv',
#  '/Users/dlc/Documents/onderzoek/AirSacTracker/Toolkit/module_circleestimation/data/example8DLC_resnet101_Deep_AirSacTrackingV1Jan1shuffle1_500000.csv']

# %%
# set parameters

threshold = 0.6

# %%
def estimateInitialGuessCircle(XY):
    # estimate initial guess for circle LM
    x0 = np.mean(XY["x"].values)
    y0 = np.mean(XY["y"].values)
    r0 = np.mean(
        np.sqrt((XY["x"].values ** 2 + x0**2) + (XY["y"].values ** 2 + y0**2))
    )
    ParIni = [x0, y0, r0]
    return ParIni

# %%
def Landau(XY, ParIni=np.NAN, epsilon=0.0001, IterMax=800):
    if np.isnan(ParIni):
        ParIni = estimateInitialGuessCircle(XY)

    centroidx = np.mean(XY["x"].values)
    centroidy = np.mean(XY["y"].values)
    centroid = [centroidx, centroidy]
    X = XY["x"].values - centroid[0]
    Y = XY["y"].values - centroid[1]
    centroid = centroid + [0]

    ParNew = [a - b for a, b in zip(ParIni, centroid)]

    for i in range(0, IterMax + 1):
        ParOld = ParNew
        Dx = X - ParOld[0]
        Dy = Y - ParOld[1]
        Dx_squared = Dx * Dx
        Dy_squared = Dy * Dy
        D = np.sqrt([sum(x) for x in zip(Dx_squared, Dy_squared)])
        ParNew = [
            -np.mean(Dx / D) * np.mean(D),
            -np.mean(Dy / D) * np.mean(D),
            np.mean(D),
        ]

        progress = np.linalg.norm([new - old for new, old in zip(ParNew, ParOld)]) / (
            np.linalg.norm(ParOld) + epsilon
        )

        if progress < epsilon:
            break

    Par = [sum(x) for x in zip(ParOld, centroid)]

    return Par

# %%
def data_prep_radius_estim_DLC(data):
    def circle_format(df_sub):
        df_all = []

        df = pd.DataFrame(columns=["x", "y", "likelihood", "frame"])
        for frame in range(1, df_sub.shape[0]):  # hier kan een .unique() flag achter
            for b in range(
                1, 6
            ):  # R starts with 1 but is inclusive in endpoint, range in Python is exclusive on endpoint
                end_col = b * 3
                start_col = end_col - 3

                helper_list = (
                    df_sub.iloc[frame, start_col:end_col].values.flatten().tolist()
                )
                helper_list.append(frame)
                df.loc[len(df)] = helper_list  # add data in row b in dataframe

            df_all.append(df)

        return pd.concat(df_all)

    ## 01b: main ----

    # list of columns needed for circle estimation used later in function
    list_airsac_points = [
        "Start_outline_outer_left_x",
        "Start_outline_outer_left_y",
        "Start_outline_outer_left_likelihood",
        "Start_outline_outer_right_x",
        "Start_outline_outer_right_y",
        "Start_outline_outer_right_likelihood",
        "LowestPoint_outline_x",
        "LowestPoint_outline_y",
        "LowestPoint_outline_likelihood",
        "MidLowleft_outline_x",
        "MidLowleft_outline_y",
        "MidLowleft_outline_likelihood",
        "MidLowright_outline_x",
        "MidLowright_outline_y",
        "MidLowright_outline_likelihood",
    ]

    colnames = []
    colnames.append("frames")  # first element is a string frames
    for i in range(1, data.shape[1]):
        colnames.append("_".join([str(data.iloc[0, i]), str(data.iloc[1, i])]))

    data.columns = colnames

    df_all = data.iloc[2:, :]

    df_sub = df_all.filter(list_airsac_points)
    df_sub = df_sub.apply(pd.to_numeric)

    circle_format_data = circle_format(df_sub)
    return circle_format_data

# %%
# sub functions for normalization


def nose_eye_normalization(auto_data, min_frames=2, threshold_normalization=0.8):
    norm_data = []
    list_normalization_points = [
        "Nose_x",
        "Nose_y",
        "Nose_likelihood",
        "EyeBridge_x",
        "EyeBridge_y",
        "EyeBridge_likelihood",
    ]

    colnames = ["frames"]

    for i in range(1, auto_data.shape[1]):
        colnames.append(
            "_".join([str(auto_data.iloc[0, i]), str(auto_data.iloc[1, i])])
        )

    auto_data.columns = colnames

    df = auto_data.iloc[2:, :]
    df_sub = df.filter(items=list_normalization_points)
    df_sub = df_sub.apply(pd.to_numeric)

    def euc_dist(xbridge, xnose, ybridge, ynose):
        return np.sqrt((xbridge - xnose) ** 2 + (ybridge - ynose) ** 2)

    df_sub_normalization = df_sub.loc[
        df_sub["Nose_likelihood"] >= threshold_normalization
    ]
    df_sub_normalization = df_sub_normalization.loc[
        df_sub_normalization["EyeBridge_likelihood"] >= threshold_normalization
    ]

    if df_sub_normalization.shape[0] >= min_frames:
        distance = [
            euc_dist(
                df_sub_normalization["EyeBridge_x"],
                df_sub_normalization["Nose_x"],
                df_sub_normalization["EyeBridge_y"],
                df_sub_normalization["Nose_y"],
            )
            for i in range(0, df_sub_normalization.shape[0])
        ]
    else:
        distance = np.NAN

    norm_data = np.nanmean(distance)

    return norm_data

# %%
def from_DLC_to_circle(path, list_of_files):
    matrix = np.empty((0, 5))
    columnnames = ["radius", "x", "y", "frame", "videofile"]
    # radius_all = pd.DataFrame(matrix, columns= columnnames)
    radius_all = []
    normalization_value = pd.DataFrame(
        data=np.empty((len(list_of_files), 2)),
        columns=["normalization_value", "videofile"],
    )

    for file in range(0, len(list_of_files)):
        radius = pd.DataFrame(columns=columnnames)

        auto_data = pd.read_csv(list_of_files[file])

        data_circle_estimation = data_prep_radius_estim_DLC(data=auto_data)
        data_circle_estimation = data_circle_estimation.astype({"frame": "int"})
        grouped_data_circle_estimation = data_circle_estimation.loc[
            data_circle_estimation["likelihood"] > threshold
        ]
        grouped_data_circle_estimation = grouped_data_circle_estimation.groupby(
            "frame", group_keys=False
        )
        count_n = 0
        for name, group in grouped_data_circle_estimation:
            if len(grouped_data_circle_estimation) > 0:
                frame_data = group
                if frame_data.shape[0] >= 3:
                    circles_LAN = Landau(
                        frame_data.iloc[:, 0:2],
                        ParIni=np.NAN,
                        epsilon=1e-06,
                        IterMax=500,
                    )
                else:
                    circles_LAN = [np.NAN, np.NAN, np.NAN, np.NAN]
                circles_res = [
                    circles_LAN[2],
                    circles_LAN[0],
                    circles_LAN[1],
                    count_n,
                    list_of_files[file],
                ]

                radius.loc[len(radius)] = circles_res

            count_n += 1
        radius_all.append(radius)
        normalization_value["normalization_value"][file] = nose_eye_normalization(
            auto_data
        )
        normalization_value["videofile"][file] = list_of_files[file]
    radius_all = pd.concat(radius_all)
    results_I = [radius_all, normalization_value]
    results = pd.merge(results_I[0], results_I[1], how="left", on="videofile")

    results["norm_radius"] = pd.to_numeric(
        results["radius"] / results["normalization_value"]
    )

    return results

# %%
results = from_DLC_to_circle(path=path, list_of_files=list_of_files)
# Out:
# 0
# 26
# 1
# 28
# 2
# /var/folders/zp/cw2_g85n5cz9ld1j0cm098f40000gp/T/ipykernel_92162/4236417957.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   normalization_value['normalization_value'][file] = nose_eye_normalization(auto_data)
# 1188
# /var/folders/zp/cw2_g85n5cz9ld1j0cm098f40000gp/T/ipykernel_92162/4236417957.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   normalization_value['normalization_value'][file] = nose_eye_normalization(auto_data)

# %%
results.to_csv(path_output + "/" + savename + "_DLC_toRadii.csv")
results.to_csv(timeseries_folder + savename + ".csv", na_rep="NA")

# %% [markdown]
# Dan hier de hough transform

# %% [markdown]
# # Module to process video with hough transform
#
# This module belongs to the manuscript "Burchardt, L., Kehy, M., Gamba, M., Ravignani, A., Pouw, W. A complete computational and data toolkit for the dynamic study of laryngeal air sacs in Siamang (Symphalangus syndactylus) with applications for spherical tracking in other animals".

# %%
# set videofolder
videofolder = "./module_hough/videos/"
outputfolder = "./module_hough/results/replications_Y/"
# version 2, using videos #################### loading in the videos
vids = [f for f in os.listdir(videofolder) if isfile(join(videofolder, f))]
vidlist = []

for i in vids:  # add the image folder name to get the full path
    vidlist.append(videofolder + i)

# %%
# Example video
Video(videofolder + vids[0], width=300, height=200)
# Out:
# <video src="./module_hough/videos/example8.mp4" controls  width="300"  height="200">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# # Main presets

# %%
# preset settings preprocessing (thresh 1 and 2 are also weighted and then passed to hough transform)
medianblur_preset = 27
dilation_preset = 5
alpha_preset = 2
beta_preset = 30
thresh_div_1_preset = 5
thresh_div_2_preset = 14

# hough presets
dp_preset = 1
minDist_preset = 10000
maxRadius_preset = 270

# %% [markdown]
# ## Main Functions

# %%
def preprocessing(
    image,
    medianblur=medianblur_preset,
    dilation=dilation_preset,
    alpha=alpha_preset,
    beta=beta_preset,
    thresh_div_1=thresh_div_1_preset,
    thresh_div_2=thresh_div_2_preset,
):
    # image0 = hougdraw(image)
    # convert to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    # brightness change
    gray = cv2.convertScaleAbs(gray, alpha=alpha, beta=beta)
    # set dynamic tresholds for canny (we will also pass this to the hough)
    mean_intensity = np.median(gray)
    threshold1 = int(max(0, (1.0 - 0.33) * mean_intensity / thresh_div_1))
    threshold2 = int(min(255, (1.0 + 0.33) * mean_intensity / thresh_div_2))
    # blur
    image2 = cv2.medianBlur(gray, medianblur)
    # dynamic thresholds for canny edge detection based on intensity of image
    # Thresholds one standard deviation above and below median intensity
    # edge detection
    image3 = cv2.Canny(image2, threshold1, threshold2)
    # dilation and second blur
    submitted = cv2.dilate(image3, None, iterations=dilation)
    image4 = cv2.medianBlur(submitted, medianblur)
    # add hough
    image4 = np.float32(image4)
    return image4, threshold1, threshold2


def preprocess_hough_apply_to_frame(image, mindist=10000, maxradius=250):
    image, param1, param2 = preprocessing(image=image)
    image = cv2.normalize(
        src=image,
        dst=None,
        alpha=0,
        beta=255,
        norm_type=cv2.NORM_MINMAX,
        dtype=cv2.CV_8U,
    )
    circles = cv2.HoughCircles(
        image,
        cv2.HOUGH_GRADIENT,
        param1=param1,
        param2=param2,
        dp=dp_preset,
        minDist=minDist_preset,
        maxRadius=maxRadius_preset,
    )
    return circles

# %% [markdown]
# # Loop throuh video folder and process each video

# %%
#######################################
for video in vidlist:
    name = os.path.basename(video)[0:-4]
    # set up empty output dataframe
    column_names = [
        "frame",  # info on region of interest for repetability
        "x",
        "y",
        "r",
        "namefr",
        "sample_rate",
    ]  # parameters of hough circle transform
    df = pd.DataFrame(columns=column_names)
    ####################set up video settings
    cap = cv2.VideoCapture(video)  # set video to capture
    frameWidth = cap.get(cv2.CAP_PROP_FRAME_WIDTH)  # frame width
    frameHeight = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)  # frame height
    fps = cap.get(cv2.CAP_PROP_FPS)  # fps = frames per second
    num_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))  # number of frames
    # set up video writer
    fourcc = cv2.VideoWriter_fourcc(
        *"MP4V"
    )  # for different video formats you could use e.g., *'XVID'
    out = cv2.VideoWriter(
        outputfolder + name + "_tracked.mp4",
        fourcc,
        fps=fps,
        frameSize=(int(frameWidth), int(frameHeight)),
    )
    ###################loop over frames of the original video
    j = 0  # fame counter

    # set up progress bar
    with tqdm(
        total=num_frames, desc="Processing " + name, bar_format="{l_bar}{bar:50}{r_bar}"
    ) as pbar:
        # the loop over frames (will close when no more frames are left to process)
        while cap.isOpened():
            ret, frame = cap.read()
            if ret == False:
                break
            j = j + 1  # add to the frame counter
            namefr = "framenr_" + str(j) + "_framevid_" + os.path.basename(video[0:-4])
            ############################detect circles
            to_be_processed_frame = frame.copy()  # we keep the original frame
            # apply hough
            circles = preprocess_hough_apply_to_frame(to_be_processed_frame)
            # draw the circles
            if circles is not None:
                circles = np.round(circles[0, 0:1]).astype("int")
                x = circles[0, 0]  # x  + plus the shift from the roi
                y = circles[0, 1]  # y  + plus the shift from the roi
                r = circles[0, 2]
                cv2.circle(
                    frame, (x, y), r, (255, 255, 0), 2
                )  # version without drawing roi back on whole image
                # save it to a row
            if circles is None:
                x = "NA"
                y = "NA"
                r = "NA"
            # write frame
            out.write(frame)  # save the frame to the new masked video
            # write x,y,r data
            new_row = [j, x, y, r, namefr, fps]
            df.loc[len(df)] = new_row
            # now update the progress bar
            pbar.update(1)
        # release video writer
        out.release()
        cap.release()
        # save csv file with the timeseries results
        df.to_csv(outputfolder + name + ".csv", sep=",")
    print("done with processing video " + name)
# Out:
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Processing example8: 100%|██████████████████████████████████████████████████| 1195/1195 [01:43<00:00, 11.60it/s]
# done with processing video example8

# %% [markdown]
# En dan als laatste de plotvideos :)

# %%
tsfol = "./module_plotcirclesonvideos/timeseries/"  # this is where your timeseries are with the same name as the complementary video
vidfol = ".module_plotcirclesonvideos/original_videos/"  # this is where the original videos are, that need a circle added
outfol = ".module_plotcirclesonvideos/output_videos_with_circles/"  # this is where you can collect your output
toprocess = os.listdir(tsfol)  # list all the time series files

#Uncomment for absolute path Yana PC
# tsfol = "/Users/dlc/Documents/onderzoek/AirSacTracker/Toolkit/module_circleestimation/results/replications_Y/"
#vidfol = "/Users/dlc/Documents/onderzoek/AirSacTracker/Toolkit/module_plotcirclesonvideos/original_videos/"
#outfol = "/Users/dlc/Documents/onderzoek/AirSacTracker/Toolkit/module_plotcirclesonvideos/output_videos_with_circles/replications_Y_07_23/"

for tt in toprocess:
    ts = pd.read_csv(tsfol + tt)  # get the time series
    idname = tt[0 : len(tt) - 4]  # remove the .csv
    vidloc = vidfol + idname + ".mp4"  # add mp4 (we assume we only process mp4s!)
    cap = cv2.VideoCapture(vidloc)  # open the video
    frameWidth = cap.get(
        cv2.CAP_PROP_FRAME_WIDTH
    )  # get the framewidth, and use it for the new video
    frameHeight = cap.get(
        cv2.CAP_PROP_FRAME_HEIGHT
    )  # get the framewidth, and use it for the new video
    fps = cap.get(cv2.CAP_PROP_FPS)  # fps = frames per second
    # what should we write to?
    out = cv2.VideoWriter(
        outfol + idname + "_circle.mp4",
        cv2.VideoWriter_fourcc(*"MP4V"),
        fps,
        (int(frameWidth), int(frameHeight)),
    )
    print("working on video: " + idname)
    while cap.isOpened():
        ret, frame = cap.read()
        if ret == False:
            break
        frame_number = int(cap.get(cv2.CAP_PROP_POS_FRAMES))

        index_var = (
            ts["frame"] == frame_number
        )  # get the index of the timeseries for the current frame number
        dat = ts.loc[index_var, :]  # get the slice of data for this frame
        for index, row in dat.iterrows():
            if (
                math.isnan(row["radius"]) == False
            ):  # only draw a circle when there a no NaN's
                cv2.circle(
                    frame,
                    (int(row["x"]), int(row["y"])),
                    int(row["radius"]),
                    (200, 0, 0),
                    2,
                )  # draw circle
        out.write(frame)  # save it into a new frame

# cleaning up
out.release()  # release the output video
cap.release()  # release the original video
print(
    "We are all done, go look into your output folder: " + str(os.path.abspath(outfol))
)
# Out:
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# working on video: example8
#     Unnamed: 0      radius           x           y  frame  \
# 1            1         NaN         NaN         NaN      1
# 27          27         NaN         NaN         NaN      1
# 55          55  121.288233  871.135345  689.953977      1
#
#                                             videofile  normalization_value  \
# 1   /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 27  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 55  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 1           NaN
# 27          NaN
# 55     2.576743
#     Unnamed: 0     radius           x           y  frame  \
# 2            2        NaN         NaN         NaN      2
# 28          28        NaN         NaN         NaN      2
# 56          56  39.031846  840.140991  800.526733      2
#
#                                             videofile  normalization_value  \
# 2   /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 28  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 56  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 2           NaN
# 28          NaN
# 56     0.829223
#     Unnamed: 0      radius            x           y  frame  \
# 3            3  198.712971   936.234832  540.340418      3
# 29          29   99.049971  1037.959900  621.253143      3
# 57          57  120.731361   867.967636  690.845021      3
#
#                                             videofile  normalization_value  \
# 3   /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 29  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 57  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 3      7.412733
# 29     2.310863
# 57     2.564912
#     Unnamed: 0      radius            x           y  frame  \
# 4            4  173.118879  1048.964172  564.432556      4
# 30          30   46.385535  1111.774902  635.805420      4
# 58          58  114.905023   870.227645  696.561251      4
#
#                                             videofile  normalization_value  \
# 4   /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 30  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 58  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 4      6.457978
# 30     1.082187
# 58     2.441133
#     Unnamed: 0      radius            x           y  frame  \
# 5            5  228.120644   905.042917  548.034015      5
# 31          31  103.620664  1038.700470  627.719025      5
# 59          59  118.461787   868.771583  693.097086      5
#
#                                             videofile  normalization_value  \
# 5   /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 31  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 59  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 5      8.509749
# 31     2.417499
# 59     2.516696
#     Unnamed: 0      radius            x           y  frame  \
# 6            6  230.264914   906.128480  550.962123      6
# 32          32   95.912373  1052.415863  640.459564      6
# 60          60  111.097874   864.913392  700.683036      6
#
#                                             videofile  normalization_value  \
# 6   /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 32  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 60  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 6      8.589738
# 32     2.237662
# 60     2.360251
#     Unnamed: 0      radius            x           y  frame  \
# 7            7         NaN          NaN         NaN      7
# 33          33  104.361574  1033.529880  594.172650      7
# 61          61   30.451648   836.477722  805.767761      7
#
#                                             videofile  normalization_value  \
# 7   /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 33  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 61  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 7           NaN
# 33     2.434785
# 61     0.646939
#     Unnamed: 0      radius            x           y  frame  \
# 8            8  208.202022   994.058960  584.563965      8
# 34          34  104.541650  1032.614940  595.818787      8
# 62          62  119.231428   852.980341  694.763148      8
#
#                                             videofile  normalization_value  \
# 8   /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 34  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 62  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 8      7.766710
# 34     2.438986
# 62     2.533047
#     Unnamed: 0      radius            x           y  frame  \
# 9            9  215.173418   961.336671  571.789734      9
# 35          35   99.565614  1021.236255  609.478455      9
# 63          63   67.380528   799.151031  776.799530      9
#
#                                             videofile  normalization_value  \
# 9   /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 35  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 63  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 9      8.026769
# 35     2.322894
# 63     1.431485
#     Unnamed: 0      radius            x           y  frame  \
# 10          10  308.047178  1198.466070  661.145602     10
# 36          36   96.835556  1006.364380  638.219025     10
# 64          64   33.148336   823.614716  809.392578     10
#
#                                             videofile  normalization_value  \
# 10  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 36  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 64  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 10    11.491306
# 36     2.259200
# 64     0.704229
#     Unnamed: 0      radius            x           y  frame  \
# 11          11  208.339565   958.728675  561.257047     11
# 37          37  107.405214  1029.242798  632.995453     11
# 65          65  112.682238   847.767297  708.939614     11
#
#                                             videofile  normalization_value  \
# 11  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 37  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 65  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 11     7.771841
# 37     2.505794
# 65     2.393910
#     Unnamed: 0      radius            x           y  frame  \
# 12          12  215.294331  1000.615356  591.054749     12
# 38          38  107.611285  1015.671542  609.786847     12
# 66          66   55.428382   807.085114  800.805939     12
#
#                                             videofile  normalization_value  \
# 12  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 38  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 66  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 12     8.031279
# 38     2.510601
# 66     1.177564
#     Unnamed: 0      radius            x           y  frame  \
# 13          13  340.734449  1233.055358  683.347197     13
# 39          39   40.924321   915.296692  636.842529     13
# 67          67   30.569474   824.859467  817.196320     13
#
#                                             videofile  normalization_value  \
# 13  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 39  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 67  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 13    12.710663
# 39     0.954776
# 67     0.649442
#     Unnamed: 0      radius            x           y  frame  \
# 14          14   16.296111  1070.736206  380.194321     14
# 40          40  112.446970  1011.877107  610.902302     14
# 68          68   51.541836   804.337372  806.221283     14
#
#                                             videofile  normalization_value  \
# 14  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 40  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 68  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 14     0.607906
# 40     2.623419
# 68     1.094995
#     Unnamed: 0      radius           x           y  frame  \
# 15          15  214.242117  949.534666  551.873660     15
# 41          41  143.489528  997.056796  582.003444     15
# 69          69   30.599982  818.574829  816.701965     15
#
#                                             videofile  normalization_value  \
# 15  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 41  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 69  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 15     7.992028
# 41     3.347651
# 69     0.650090
#     Unnamed: 0      radius            x           y  frame  \
# 16          16  348.733235  1239.732428  682.116103     16
# 42          42   35.236461  1061.212952  705.906372     16
# 70          70   65.634949   788.528931  791.533478     16
#
#                                             videofile  normalization_value  \
# 16  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 42  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 70  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 16    13.009047
# 42     0.822076
# 70     1.394401
#     Unnamed: 0      radius            x           y  frame  \
# 17          17  425.997947  1310.531513  729.737305     17
# 43          43  117.573911   989.791510  613.635352     17
# 71          71  112.742761   829.179414  710.565854     17
#
#                                             videofile  normalization_value  \
# 17  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 43  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 71  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 17    15.891308
# 43     2.743032
# 71     2.395196
#     Unnamed: 0      radius           x           y  frame  \
# 18          18  221.470618  966.828139  564.342476     18
# 44          44  115.940019  984.798579  617.323749     18
# 72          72   53.737039  788.505310  801.152008     18
#
#                                             videofile  normalization_value  \
# 18  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 44  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 72  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 18     8.261678
# 44     2.704913
# 72     1.141632
#     Unnamed: 0      radius            x           y  frame  \
# 19          19  391.371169  1276.020386  710.912034     19
# 45          45  114.560029   984.499596  618.935791     19
# 73          73  120.020146   834.053532  704.404566     19
#
#                                             videofile  normalization_value  \
# 19  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 45  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 73  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 19    14.599601
# 45     2.672717
# 73     2.549803
#     Unnamed: 0      radius            x           y  frame  \
# 20          20  395.327248  1276.665350  715.242221     20
# 46          46   75.692875  1051.215729  671.883362     20
# 74          74   33.437333   799.867889  815.628448     20
#
#                                             videofile  normalization_value  \
# 20  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 46  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 74  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 20    14.747177
# 46     1.765936
# 74     0.710369
#     Unnamed: 0      radius            x           y  frame  \
# 21          21  226.000023   977.093739  567.816809     21
# 47          47   32.978760  1097.753357  649.396606     21
# 75          75   35.629995   799.005310  813.348511     21
#
#                                             videofile  normalization_value  \
# 21  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 47  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 75  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 21     8.430642
# 47     0.769404
# 75     0.756952
#     Unnamed: 0      radius            x           y  frame  \
# 22          22  377.138793  1255.013540  702.312118     22
# 48          48   38.982259  1100.778809  646.484528     22
# 76          76   35.364369   798.121643  813.070190     22
#
#                                             videofile  normalization_value  \
# 22  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 48  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 76  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 22    14.068680
# 48     0.909467
# 76     0.751309
#     Unnamed: 0      radius            x           y  frame  \
# 23          23  357.016151  1233.108163  689.572014     23
# 49          49  112.854455  1000.871834  618.972340     23
# 77          77  119.095550   833.129072  701.685052     23
#
#                                             videofile  normalization_value  \
# 23  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 49  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 77  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 23    13.318031
# 49     2.632926
# 77     2.530160
#     Unnamed: 0      radius            x           y  frame  \
# 24          24  289.050224  1169.904214  640.405625     24
# 50          50  119.791119   995.927839  614.075201     24
# 78          78   39.487041   805.030518  807.359222     24
#
#                                             videofile  normalization_value  \
# 24  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 50  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 78  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 24    10.782649
# 50     2.794760
# 78     0.838894
#     Unnamed: 0      radius            x           y  frame  \
# 25          25  165.271360   997.958873  502.712781     25
# 51          51   43.147976  1061.188904  705.105774     25
# 79          79   40.437920   805.131622  806.569885     25
#
#                                             videofile  normalization_value  \
# 25  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            26.806978
# 51  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 79  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 25     6.165237
# 51     1.006654
# 79     0.859095
#     Unnamed: 0     radius            x           y  frame  \
# 52          52  123.36369  1000.582658  607.578012     26
# 80          80   44.46594   802.854034  803.260254     26
#
#                                             videofile  normalization_value  \
# 52  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 80  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 52     2.878109
# 80     0.944670
#     Unnamed: 0      radius            x           y  frame  \
# 53          53  121.136355  1000.365423  610.219907     27
# 81          81  110.744252   823.105858  703.918306     27
#
#                                             videofile  normalization_value  \
# 53  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            42.862755
# 81  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 53     2.826145
# 81     2.352738
#     Unnamed: 0     radius           x           y  frame  \
# 82          82  43.483626  798.980713  802.555237     28
#
#                                             videofile  normalization_value  \
# 82  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 82       0.9238
#     Unnamed: 0      radius           x           y  frame  \
# 83          83  132.070792  835.747496  683.208989     29
#
#                                             videofile  normalization_value  \
# 83  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 83     2.805816
#     Unnamed: 0     radius          x           y  frame  \
# 84          84  42.754933  795.04483  802.371155     30
#
#                                             videofile  normalization_value  \
# 84  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 84      0.90832
#     Unnamed: 0      radius           x           y  frame  \
# 85          85  100.029505  817.706739  715.755969     31
#
#                                             videofile  normalization_value  \
# 85  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 85     2.125106
#     Unnamed: 0      radius           x           y  frame  \
# 86          86  112.647527  821.286448  701.473885     32
#
#                                             videofile  normalization_value  \
# 86  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 86     2.393173
#     Unnamed: 0     radius           x           y  frame  \
# 87          87  60.689245  782.180145  787.965485     33
#
#                                             videofile  normalization_value  \
# 87  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 87      1.28933
#     Unnamed: 0      radius           x           y  frame  \
# 88          88  114.661195  820.572725  699.258215     34
#
#                                             videofile  normalization_value  \
# 88  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 88     2.435953
#     Unnamed: 0     radius           x          y  frame  \
# 89          89  38.425711  794.326172  804.66214     35
#
#                                             videofile  normalization_value  \
# 89  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 89     0.816346
#     Unnamed: 0      radius           x           y  frame  \
# 90          90  114.717596  813.838109  699.658949     36
#
#                                             videofile  normalization_value  \
# 90  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 90     2.437151
#     Unnamed: 0      radius           x           y  frame  \
# 91          91  117.988793  813.566007  697.753347     37
#
#                                             videofile  normalization_value  \
# 91  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 91     2.506647
#     Unnamed: 0      radius           x          y  frame  \
# 92          92  118.554209  810.564463  699.02711     38
#
#                                             videofile  normalization_value  \
# 92  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 92     2.518659
#     Unnamed: 0      radius           x           y  frame  \
# 93          93  114.073875  805.882701  704.582268     39
#
#                                             videofile  normalization_value  \
# 93  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 93     2.423475
#     Unnamed: 0      radius           x           y  frame  \
# 94          94  108.298846  797.633218  712.687946     40
#
#                                             videofile  normalization_value  \
# 94  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 94     2.300786
#     Unnamed: 0      radius           x           y  frame  \
# 95          95  110.719075  797.208467  711.555407     41
#
#                                             videofile  normalization_value  \
# 95  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 95     2.352203
#     Unnamed: 0      radius           x          y  frame  \
# 96          96  111.353327  796.730631  712.18457     42
#
#                                             videofile  normalization_value  \
# 96  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 96     2.365678
#     Unnamed: 0      radius           x           y  frame  \
# 97          97  108.305226  793.334203  714.970238     43
#
#                                             videofile  normalization_value  \
# 97  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 97     2.300922
#     Unnamed: 0      radius           x           y  frame  \
# 98          98  103.446215  790.454046  720.974329     44
#
#                                             videofile  normalization_value  \
# 98  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 98     2.197693
#     Unnamed: 0     radius           x           y  frame  \
# 99          99  46.201354  762.153015  806.923309     45
#
#                                             videofile  normalization_value  \
# 99  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#     norm_radius
# 99     0.981538
#      Unnamed: 0     radius           x           y  frame  \
# 100         100  51.050068  758.732666  803.464355     46
#
#                                              videofile  normalization_value  \
# 100  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 100     1.084548
#      Unnamed: 0      radius           x          y  frame  \
# 101         101  117.899055  797.980325  704.79543     47
#
#                                              videofile  normalization_value  \
# 101  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 101     2.504741
#      Unnamed: 0      radius           x           y  frame  \
# 102         102  100.805257  790.546148  724.135744     48
#
#                                              videofile  normalization_value  \
# 102  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 102     2.141586
#      Unnamed: 0      radius           x         y  frame  \
# 103         103  124.516789  804.725662  701.1683     49
#
#                                              videofile  normalization_value  \
# 103  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 103     2.645333
#      Unnamed: 0     radius          x           y  frame  \
# 104         104  52.530244  755.71344  806.953247     50
#
#                                              videofile  normalization_value  \
# 104  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 104     1.115994
#      Unnamed: 0     radius           x           y  frame  \
# 105         105  48.771962  757.177063  809.407379     51
#
#                                              videofile  normalization_value  \
# 105  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 105      1.03615
#      Unnamed: 0      radius           x           y  frame  \
# 106         106  108.558726  789.373128  717.913221     52
#
#                                              videofile  normalization_value  \
# 106  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 106     2.306307
#      Unnamed: 0     radius           x          y  frame  \
# 107         107  48.254069  753.069427  808.89624     53
#
#                                              videofile  normalization_value  \
# 107  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 107     1.025148
#      Unnamed: 0     radius           x           y  frame  \
# 108         108  44.413798  751.297241  809.090271     54
#
#                                              videofile  normalization_value  \
# 108  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 108     0.943562
#      Unnamed: 0     radius           x           y  frame  \
# 109         109  45.460574  752.551178  803.724579     55
#
#                                              videofile  normalization_value  \
# 109  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 109       0.9658
#      Unnamed: 0      radius           x           y  frame  \
# 110         110  101.376248  783.285076  715.693756     56
#
#                                              videofile  normalization_value  \
# 110  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 110     2.153717
#      Unnamed: 0      radius           x           y  frame  \
# 111         111  108.268518  783.236055  702.254684     57
#
#                                              videofile  normalization_value  \
# 111  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 111     2.300142
#      Unnamed: 0     radius           x           y  frame  \
# 112         112  49.212524  746.562378  789.591522     58
#
#                                              videofile  normalization_value  \
# 112  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 112      1.04551
#      Unnamed: 0     radius           x           y  frame  \
# 113         113  48.011432  745.279968  785.874359     59
#
#                                              videofile  normalization_value  \
# 113  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 113     1.019993
#      Unnamed: 0      radius           x           y  frame  \
# 114         114  119.369068  788.933009  683.935578     60
#
#                                              videofile  normalization_value  \
# 114  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 114     2.535971
#      Unnamed: 0     radius           x           y  frame  \
# 115         115  45.359331  746.469238  783.910889     61
#
#                                              videofile  normalization_value  \
# 115  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 115     0.963649
#      Unnamed: 0     radius           x           y  frame  \
# 116         116  120.52952  790.692767  681.655795     62
#
#                                              videofile  normalization_value  \
# 116  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 116     2.560624
#      Unnamed: 0      radius           x           y  frame  \
# 117         117  113.243761  788.173507  688.711142     63
#
#                                              videofile  normalization_value  \
# 117  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 117      2.40584
#      Unnamed: 0      radius           x           y  frame  \
# 118         118  122.199428  794.505426  677.572644     64
#
#                                              videofile  normalization_value  \
# 118  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 118     2.596101
#      Unnamed: 0      radius           x          y  frame  \
# 119         119  110.932721  788.936458  687.07386     65
#
#                                              videofile  normalization_value  \
# 119  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 119     2.356742
#      Unnamed: 0     radius           x           y  frame  \
# 120         120  94.917223  772.695804  704.983603     66
#
#                                              videofile  normalization_value  \
# 120  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 120     2.016496
#      Unnamed: 0     radius           x           y  frame  \
# 121         121  76.981119  736.672699  748.249603     67
#
#                                              videofile  normalization_value  \
# 121  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 121     1.635448
#      Unnamed: 0     radius          x           y  frame  \
# 122         122  97.008408  776.59395  705.529456     68
#
#                                              videofile  normalization_value  \
# 122  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 122     2.060923
#      Unnamed: 0      radius           x          y  frame  \
# 123         123  101.807154  784.389915  696.41114     69
#
#                                              videofile  normalization_value  \
# 123  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 123     2.162872
#      Unnamed: 0     radius           x           y  frame  \
# 124         124  94.178369  782.135394  702.703222     70
#
#                                              videofile  normalization_value  \
# 124  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 124       2.0008
#      Unnamed: 0     radius           x           y  frame  \
# 125         125  93.159797  785.117238  704.609158     71
#
#                                              videofile  normalization_value  \
# 125  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 125      1.97916
#      Unnamed: 0     radius           x           y  frame  \
# 126         126  93.478166  784.505388  706.662397     72
#
#                                              videofile  normalization_value  \
# 126  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 126     1.985924
#      Unnamed: 0     radius           x           y  frame  \
# 127         127  94.986079  782.938991  702.260631     73
#
#                                              videofile  normalization_value  \
# 127  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 127     2.017959
#      Unnamed: 0     radius           x           y  frame  \
# 128         128  94.450214  784.427979  704.580046     74
#
#                                              videofile  normalization_value  \
# 128  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 128     2.006575
#      Unnamed: 0     radius           x           y  frame  \
# 129         129  94.669412  783.966622  703.854585     75
#
#                                              videofile  normalization_value  \
# 129  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 129     2.011232
#      Unnamed: 0     radius           x          y  frame  \
# 130         130  91.853404  785.489717  705.34639     76
#
#                                              videofile  normalization_value  \
# 130  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 130     1.951406
#      Unnamed: 0     radius           x           y  frame  \
# 131         131  94.398264  782.860798  705.272944     77
#
#                                              videofile  normalization_value  \
# 131  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 131     2.005471
#      Unnamed: 0    radius           x           y  frame  \
# 132         132  93.12427  787.579937  703.734581     78
#
#                                              videofile  normalization_value  \
# 132  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 132     1.978406
#      Unnamed: 0     radius           x           y  frame  \
# 133         133  94.947936  786.062353  700.084434     79
#
#                                              videofile  normalization_value  \
# 133  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 133     2.017149
#      Unnamed: 0     radius           x           y  frame  \
# 134         134  93.936552  789.426311  698.712864     80
#
#                                              videofile  normalization_value  \
# 134  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 134     1.995662
#      Unnamed: 0     radius           x           y  frame  \
# 135         135  95.862339  788.138715  698.321513     81
#
#                                              videofile  normalization_value  \
# 135  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 135     2.036575
#      Unnamed: 0    radius           x           y  frame  \
# 136         136  92.77595  789.659296  698.325014     82
#
#                                              videofile  normalization_value  \
# 136  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 136     1.971006
#      Unnamed: 0     radius           x           y  frame  \
# 137         137  94.833662  787.834551  694.532027     83
#
#                                              videofile  normalization_value  \
# 137  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 137     2.014721
#      Unnamed: 0     radius           x           y  frame  \
# 138         138  94.793113  787.615698  693.111885     84
#
#                                              videofile  normalization_value  \
# 138  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 138      2.01386
#      Unnamed: 0     radius           x           y  frame  \
# 139         139  92.954019  789.831627  694.140477     85
#
#                                              videofile  normalization_value  \
# 139  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 139     1.974789
#      Unnamed: 0     radius           x           y  frame  \
# 140         140  93.304204  789.651755  695.769942     86
#
#                                              videofile  normalization_value  \
# 140  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 140     1.982228
#      Unnamed: 0    radius           x          y  frame  \
# 141         141  95.03667  789.178262  695.47014     87
#
#                                              videofile  normalization_value  \
# 141  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 141     2.019034
#      Unnamed: 0     radius           x           y  frame  \
# 142         142  94.874299  790.083426  698.213062     88
#
#                                              videofile  normalization_value  \
# 142  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 142     2.015585
#      Unnamed: 0     radius           x           y  frame  \
# 143         143  93.888125  789.252966  701.071809     89
#
#                                              videofile  normalization_value  \
# 143  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 143     1.994633
#      Unnamed: 0     radius           x           y  frame  \
# 144         144  93.614885  788.601964  702.226366     90
#
#                                              videofile  normalization_value  \
# 144  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 144     1.988829
#      Unnamed: 0     radius           x           y  frame  \
# 145         145  93.770618  789.793152  702.030731     91
#
#                                              videofile  normalization_value  \
# 145  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 145     1.992137
#      Unnamed: 0     radius           x           y  frame  \
# 146         146  93.283173  792.146472  702.206915     92
#
#                                              videofile  normalization_value  \
# 146  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 146     1.981781
#      Unnamed: 0     radius           x           y  frame  \
# 147         147  94.488859  791.822901  696.702459     93
#
#                                              videofile  normalization_value  \
# 147  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 147     2.007396
#      Unnamed: 0     radius           x           y  frame  \
# 148         148  92.824223  793.453245  699.834087     94
#
#                                              videofile  normalization_value  \
# 148  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 148     1.972031
#      Unnamed: 0     radius           x           y  frame  \
# 149         149  92.028641  797.236382  701.370591     95
#
#                                              videofile  normalization_value  \
# 149  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 149     1.955129
#      Unnamed: 0     radius           x           y  frame  \
# 150         150  92.981358  800.566194  703.562273     96
#
#                                              videofile  normalization_value  \
# 150  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 150     1.975369
#      Unnamed: 0     radius           x           y  frame  \
# 151         151  97.066103  799.107608  698.860571     97
#
#                                              videofile  normalization_value  \
# 151  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 151     2.062149
#      Unnamed: 0     radius           x           y  frame  \
# 152         152  95.511441  806.789147  702.612377     98
#
#                                              videofile  normalization_value  \
# 152  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 152      2.02912
#      Unnamed: 0     radius           x           y  frame  \
# 153         153  94.664706  814.856418  704.164029     99
#
#                                              videofile  normalization_value  \
# 153  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 153     2.011132
#      Unnamed: 0    radius           x          y  frame  \
# 154         154  98.02025  820.505007  701.96505    100
#
#                                              videofile  normalization_value  \
# 154  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 154      2.08242
#      Unnamed: 0     radius           x           y  frame  \
# 155         155  93.844263  828.211508  707.276883    101
#
#                                              videofile  normalization_value  \
# 155  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 155     1.993702
#      Unnamed: 0      radius           x          y  frame  \
# 156         156  128.593434  798.266304  683.69706    102
#
#                                              videofile  normalization_value  \
# 156  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 156      2.73194
#      Unnamed: 0     radius           x           y  frame  \
# 157         157  98.723122  835.584658  699.640279    103
#
#                                              videofile  normalization_value  \
# 157  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 157     2.097352
#      Unnamed: 0     radius           x           y  frame  \
# 158         158  93.581019  842.600926  707.919877    104
#
#                                              videofile  normalization_value  \
# 158  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 158     1.988109
#      Unnamed: 0     radius           x           y  frame  \
# 159         159  98.273382  849.486921  700.657845    105
#
#                                              videofile  normalization_value  \
# 159  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 159     2.087797
#      Unnamed: 0     radius           x           y  frame  \
# 160         160  98.910489  850.068328  702.474568    106
#
#                                              videofile  normalization_value  \
# 160  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 160     2.101333
#      Unnamed: 0   radius           x          y  frame  \
# 161         161  84.8415  856.574236  724.32856    107
#
#                                              videofile  normalization_value  \
# 161  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 161      1.80244
#      Unnamed: 0     radius          x           y  frame  \
# 162         162  94.685257  854.88815  716.766724    108
#
#                                              videofile  normalization_value  \
# 162  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 162     2.011568
#      Unnamed: 0      radius           x          y  frame  \
# 163         163  119.954752  844.553065  695.89313    109
#
#                                              videofile  normalization_value  \
# 163  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 163     2.548413
#      Unnamed: 0      radius           x           y  frame  \
# 164         164  103.487679  860.991402  703.412361    110
#
#                                              videofile  normalization_value  \
# 164  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 164     2.198574
#      Unnamed: 0     radius          x           y  frame  \
# 165         165  90.433184  865.53222  726.146006    111
#
#                                              videofile  normalization_value  \
# 165  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 165     1.921234
#      Unnamed: 0     radius           x           y  frame  \
# 166         166  39.912561  924.879822  789.512634    112
#
#                                              videofile  normalization_value  \
# 166  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 166     0.847934
#      Unnamed: 0      radius           x           y  frame  \
# 167         167  101.052453  884.546431  713.707812    113
#
#                                              videofile  normalization_value  \
# 167  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 167     2.146838
#      Unnamed: 0     radius           x           y  frame  \
# 168         168  106.79601  901.181363  714.258975    114
#
#                                              videofile  normalization_value  \
# 168  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 168     2.268859
#      Unnamed: 0      radius           x           y  frame  \
# 169         169  103.359304  898.932946  723.578815    115
#
#                                              videofile  normalization_value  \
# 169  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 169     2.195847
#      Unnamed: 0     radius           x           y  frame  \
# 170         170  69.398531  858.258026  785.406921    116
#
#                                              videofile  normalization_value  \
# 170  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 170     1.474357
#      Unnamed: 0     radius           x           y  frame  \
# 171         171  67.809053  861.619995  789.999451    117
#
#                                              videofile  normalization_value  \
# 171  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 171     1.440589
#      Unnamed: 0      radius           x           y  frame  \
# 172         172  144.347654  923.049231  674.136386    118
#
#                                              videofile  normalization_value  \
# 172  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 172     3.066636
#      Unnamed: 0      radius           x           y  frame  \
# 173         173  111.592177  909.356092  717.265466    119
#
#                                              videofile  normalization_value  \
# 173  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 173     2.370752
#      Unnamed: 0      radius           x           y  frame  \
# 174         174  105.429452  909.035083  725.662167    120
#
#                                              videofile  normalization_value  \
# 174  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 174     2.239827
#      Unnamed: 0     radius           x           y  frame  \
# 175         175  97.389067  909.872301  735.663295    121
#
#                                              videofile  normalization_value  \
# 175  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 175      2.06901
#      Unnamed: 0     radius           x           y  frame  \
# 176         176  98.390195  912.831112  732.277191    122
#
#                                              videofile  normalization_value  \
# 176  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 176     2.090279
#      Unnamed: 0     radius           x           y  frame  \
# 177         177  99.134413  913.314228  734.852307    123
#
#                                              videofile  normalization_value  \
# 177  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 177      2.10609
#      Unnamed: 0      radius           x           y  frame  \
# 178         178  105.560582  912.205704  729.921769    124
#
#                                              videofile  normalization_value  \
# 178  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#      norm_radius
# 178     2.242612
#      Unnamed: 0      radius          x           y  frame  \
# ...
# 1196  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1196     3.394798
#       Unnamed: 0      radius           x           y  frame  \
# 1197        1197  159.900025  570.634277  498.408374   1143
#
#                                               videofile  normalization_value  \
# 1197  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1197     3.397042
#       Unnamed: 0      radius           x           y  frame  \
# 1198        1198  161.738019  575.795695  499.436356   1144
#
#                                               videofile  normalization_value  \
# 1198  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1198      3.43609
#       Unnamed: 0     radius           x           y  frame  \
# 1199        1199  157.89237  572.857582  490.434132   1145
#
#                                               videofile  normalization_value  \
# 1199  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1199      3.35439
#       Unnamed: 0     radius           x           y  frame  \
# 1200        1200  156.91895  572.533042  491.354264   1146
#
#                                               videofile  normalization_value  \
# 1200  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1200      3.33371
#       Unnamed: 0      radius           x           y  frame  \
# 1201        1201  164.138797  575.514388  495.442193   1147
#
#                                               videofile  normalization_value  \
# 1201  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1201     3.487094
#       Unnamed: 0      radius          x           y  frame  \
# 1202        1202  160.963786  565.61315  490.601522   1148
#
#                                               videofile  normalization_value  \
# 1202  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1202     3.419642
#       Unnamed: 0      radius           x           y  frame  \
# 1203        1203  163.694328  574.159096  492.184312   1149
#
#                                               videofile  normalization_value  \
# 1203  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1203     3.477652
#       Unnamed: 0      radius           x           y  frame  \
# 1204        1204  161.449546  563.357745  490.620472   1150
#
#                                               videofile  normalization_value  \
# 1204  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1204     3.429962
#       Unnamed: 0      radius           x           y  frame  \
# 1205        1205  162.106475  562.463328  490.899704   1151
#
#                                               videofile  normalization_value  \
# 1205  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1205     3.443918
#       Unnamed: 0      radius           x           y  frame  \
# 1206        1206  160.392455  563.914203  490.627402   1152
#
#                                               videofile  normalization_value  \
# 1206  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1206     3.407504
#       Unnamed: 0      radius           x           y  frame  \
# 1207        1207  167.754783  570.031322  494.827392   1153
#
#                                               videofile  normalization_value  \
# 1207  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1207     3.563915
#       Unnamed: 0      radius           x           y  frame  \
# 1208        1208  165.011679  560.007566  490.761698   1154
#
#                                               videofile  normalization_value  \
# 1208  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1208     3.505638
#       Unnamed: 0      radius           x           y  frame  \
# 1209        1209  167.763037  558.166312  492.990884   1155
#
#                                               videofile  normalization_value  \
# 1209  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1209      3.56409
#       Unnamed: 0      radius           x           y  frame  \
# 1210        1210  171.306301  559.777219  489.594196   1156
#
#                                               videofile  normalization_value  \
# 1210  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1210     3.639366
#       Unnamed: 0      radius           x           y  frame  \
# 1211        1211  175.863812  556.453271  500.443761   1157
#
#                                               videofile  normalization_value  \
# 1211  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1211      3.73619
#       Unnamed: 0      radius           x           y  frame  \
# 1212        1212  178.050144  553.165401  502.607307   1158
#
#                                               videofile  normalization_value  \
# 1212  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1212     3.782638
#       Unnamed: 0      radius           x           y  frame  \
# 1213        1213  178.222558  547.761633  511.461051   1159
#
#                                               videofile  normalization_value  \
# 1213  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1213     3.786301
#       Unnamed: 0      radius           x           y  frame  \
# 1214        1214  176.902313  538.911181  522.746917   1160
#
#                                               videofile  normalization_value  \
# 1214  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1214     3.758252
#       Unnamed: 0      radius           x           y  frame  \
# 1215        1215  174.151158  528.213386  531.734637   1161
#
#                                               videofile  normalization_value  \
# 1215  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1215     3.699805
#       Unnamed: 0      radius          x          y  frame  \
# 1216        1216  172.573482  518.46224  534.99713   1162
#
#                                               videofile  normalization_value  \
# 1216  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1216     3.666287
#       Unnamed: 0      radius           x           y  frame  \
# 1217        1217  171.161912  507.718133  538.486136   1163
#
#                                               videofile  normalization_value  \
# 1217  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1217     3.636299
#       Unnamed: 0      radius           x           y  frame  \
# 1218        1218  168.841315  498.336832  542.224799   1164
#
#                                               videofile  normalization_value  \
# 1218  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1218     3.586998
#       Unnamed: 0      radius           x           y  frame  \
# 1219        1219  164.820241  490.310208  543.920964   1165
#
#                                               videofile  normalization_value  \
# 1219  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1219     3.501571
#       Unnamed: 0      radius           x          y  frame  \
# 1220        1220  162.363944  482.512339  543.32967   1166
#
#                                               videofile  normalization_value  \
# 1220  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1220     3.449388
#       Unnamed: 0      radius           x           y  frame  \
# 1221        1221  161.142243  475.998415  544.050937   1167
#
#                                               videofile  normalization_value  \
# 1221  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1221     3.423433
#       Unnamed: 0      radius           x           y  frame  \
# 1222        1222  159.198398  470.539282  544.077113   1168
#
#                                               videofile  normalization_value  \
# 1222  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1222     3.382136
#       Unnamed: 0      radius           x          y  frame  \
# 1223        1223  158.876675  463.690326  541.46886   1169
#
#                                               videofile  normalization_value  \
# 1223  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1223     3.375302
#       Unnamed: 0      radius           x           y  frame  \
# 1224        1224  163.559072  458.377886  534.978516   1170
#
#                                               videofile  normalization_value  \
# 1224  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1224     3.474778
#       Unnamed: 0      radius           x           y  frame  \
# 1225        1225  165.827172  451.721764  538.200716   1171
#
#                                               videofile  normalization_value  \
# 1225  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1225     3.522963
#       Unnamed: 0      radius           x           y  frame  \
# 1226        1226  161.715373  447.126688  540.531708   1172
#
#                                               videofile  normalization_value  \
# 1226  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1226     3.435609
#       Unnamed: 0      radius           x           y  frame  \
# 1227        1227  169.507302  451.248458  534.243224   1173
#
#                                               videofile  normalization_value  \
# 1227  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1227     3.601147
#       Unnamed: 0      radius           x           y  frame  \
# 1228        1228  171.374206  458.951098  527.585329   1174
#
#                                               videofile  normalization_value  \
# 1228  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1228     3.640809
#       Unnamed: 0     radius           x           y  frame  \
# 1229        1229  170.52648  454.169622  516.103594   1175
#
#                                               videofile  normalization_value  \
# 1229  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1229     3.622799
#       Unnamed: 0      radius           x           y  frame  \
# 1230        1230  167.948863  435.671382  506.139373   1176
#
#                                               videofile  normalization_value  \
# 1230  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1230     3.568038
#       Unnamed: 0      radius           x          y  frame  \
# 1231        1231  166.433654  419.188114  499.54311   1177
#
#                                               videofile  normalization_value  \
# 1231  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1231     3.535848
#       Unnamed: 0      radius           x           y  frame  \
# 1232        1232  167.821934  410.454666  483.001735   1178
#
#                                               videofile  normalization_value  \
# 1232  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1232     3.565342
#       Unnamed: 0      radius           x          y  frame  \
# 1233        1233  169.067713  411.073217  475.36336   1179
#
#                                               videofile  normalization_value  \
# 1233  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1233     3.591808
#       Unnamed: 0      radius           x           y  frame  \
# 1234        1234  165.210862  409.741859  471.744548   1180
#
#                                               videofile  normalization_value  \
# 1234  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1234      3.50987
#       Unnamed: 0      radius           x           y  frame  \
# 1235        1235  165.165168  403.994347  446.216516   1181
#
#                                               videofile  normalization_value  \
# 1235  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1235     3.508899
#       Unnamed: 0     radius           x           y  frame  \
# 1236        1236  164.32137  393.441615  416.316662   1182
#
#                                               videofile  normalization_value  \
# 1236  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1236     3.490973
#       Unnamed: 0      radius           x           y  frame  \
# 1237        1237  163.599075  384.774732  402.724161   1183
#
#                                               videofile  normalization_value  \
# 1237  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1237     3.475628
#       Unnamed: 0      radius          x           y  frame  \
# 1238        1238  166.088372  395.06449  407.719863   1184
#
#                                               videofile  normalization_value  \
# 1238  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1238     3.528513
#       Unnamed: 0      radius           x         y  frame  \
# 1239        1239  168.090661  398.722439  418.6973   1185
#
#                                               videofile  normalization_value  \
# 1239  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1239     3.571051
#       Unnamed: 0      radius           x           y  frame  \
# 1240        1240  165.899701  398.441594  420.094343   1186
#
#                                               videofile  normalization_value  \
# 1240  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1240     3.524504
#       Unnamed: 0      radius          x           y  frame  \
# 1241        1241  152.798188  334.53537  463.031296   1187
#
#                                               videofile  normalization_value  \
# 1241  /Users/dlc/Documents/onderzoek/AirSacTracker/T...            47.070365
#
#       norm_radius
# 1241     3.246165
# Empty DataFrame
# Columns: [Unnamed: 0, radius, x, y, frame, videofile, normalization_value, norm_radius]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, radius, x, y, frame, videofile, normalization_value, norm_radius]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, radius, x, y, frame, videofile, normalization_value, norm_radius]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, radius, x, y, frame, videofile, normalization_value, norm_radius]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, radius, x, y, frame, videofile, normalization_value, norm_radius]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, radius, x, y, frame, videofile, normalization_value, norm_radius]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, radius, x, y, frame, videofile, normalization_value, norm_radius]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, radius, x, y, frame, videofile, normalization_value, norm_radius]
# Index: []
# We are all done, go look into your output folder: /Users/dlc/Documents/onderzoek/AirSacTracker/Toolkit/module_plotcirclesonvideos/output_videos_with_circles/replications_Y_07_23
